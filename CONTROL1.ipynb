# %% [markdown]
# <a href="https://colab.research.google.com/github/fcarcamo03/PROG/blob/main/CONTROL1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
install.packages("dplyr")
install.packages("ggplot2")
library("dplyr")
library("ggplot2")

# %%
#carga archivo
datosP <- read.csv("https://raw.githubusercontent.com/fcarcamo03/PROG/main/CONTROL%201/DatosPaises.csv", sep = ";", header = TRUE)
 head(datosP)
# Out:
#   PAIS       PIB       POB   IDH    GINI  IPC    FAO  GENERO ELECTRICIDAD
# 1 Qatar      127.54265 2.169 0.8498 29.95 107.07 1.75 0.524   98
# 2 Luxembourg  87.77164 0.543 0.8919 29.00 108.01 1.27 0.100  100
# 3 Kuwait      82.36923 3.250 0.8163 29.00 111.19 2.60 0.387   98
# 4 Singapore   76.24004 5.399 0.9118 29.95 112.65 1.02 0.088  100
# 5 Brunei      69.44976 0.418 0.8556 29.00 102.88 2.95 0.064   76
# 6 Norway      62.45083 5.084 0.9439 26.83 104.19 1.51 0.067  100
#   ESCOLARIDAD ⋯ TURISMO INTERNET VIOLENCIA VIDA CELULAR DESERCION PRISION
# 1 13.79       ⋯  2.611  91.49    38.3      78.2 145.76  2.26       60
# 2 13.88       ⋯  0.945  94.67    39.5      81.7 148.37  5.60      122
# 3 14.75       ⋯  0.300  78.70    39.5      74.4 218.43  5.93      137
# 4 15.40       ⋯ 11.900  82.00     9.2      83.0 158.13  1.32      230
# 5 14.53       ⋯  0.225  68.77    39.5      78.8 110.06  3.63      122
# 6 17.49       ⋯  4.963  96.30    26.8      81.6 116.51  1.51       72
#   RENOVABLE PARLAMENTO INMIGRANTES
# 1  0.00      0.00      73.82
# 2  3.98     28.33      43.25
# 3  0.00      1.54      60.21
# 4  2.79     25.25      42.93
# 5  0.00     23.17      49.35
# 6 47.75     39.64      13.77

# %%
datosP %>%
  ggplot()+
 aes(IDH) +
  geom_histogram(binwidth = 0.01, fill = "lightblue", color = "black") +
  geom_vline(xintercept = c(quantile(datosP$IDH,0.03), quantile(datosP$IDH,0.97)), linetype = "dashed", color = "red")

datos_Per %>%
  ggplot()+
 aes(IDH) +
  geom_histogram(binwidth = 0.01, fill = "lightblue", color = "black") #+
  #geom_vline(xintercept = c(1, 100), linetype = "dashed", color = "red")
# Out:
# plot without title
# plot without title

# %%
ggplot(datosP, aes(x = PIB, y = IDH)) +
  geom_point() +
  geom_smooth(method = "lm")

ggplot(datos_Per, aes(x = PIB, y = IDH)) +
  geom_point() +
  geom_smooth(method = "lm")
# Out:
# `geom_smooth()` using formula = 'y ~ x'
# `geom_smooth()` using formula = 'y ~ x'
# plot without title
# plot without title

# %%
mean(datosP$IDH)
mean(datos_Per$IDH)

sd(datosP$IDH)
sd(datos_Per$IDH)

cor(datosP$PIB,datosP$IDH)
cor(datos_Per$PIB,datos_Per$IDH)
# Out:
# [1] 0.6924415
# [1] 0.6950335
# [1] 0.1547061
# [1] 0.1425
# [1] 0.7318694
# [1] 0.7115144

# %%
ggplot(datosP, aes(x = IDH, y =  1)) +
  geom_point() +
  geom_vline(xintercept = 5, linetype = "dashed", color = "red")
# Out:
# plot without title

# %%
#IDH sin datos atipicos
datos_Per <- datosP %>%
  filter(IDH >= quantile(IDH,0.03) & IDH <= quantile(IDH,0.97))

head(datos_Per)
# Out:
#   PAIS                 PIB       POB   IDH    GINI  IPC    FAO  GENERO
# 1 Qatar                127.54265 2.169 0.8498 29.95 107.07 1.75 0.524
# 2 Luxembourg            87.77164 0.543 0.8919 29.00 108.01 1.27 0.100
# 3 Kuwait                82.36923 3.250 0.8163 29.00 111.19 2.60 0.387
# 4 Singapore             76.24004 5.399 0.9118 29.95 112.65 1.02 0.088
# 5 Brunei                69.44976 0.418 0.8556 29.00 102.88 2.95 0.064
# 6 United Arab Emirates  57.04215 9.206 0.8355 29.00 102.66 1.58 0.232
#   ELECTRICIDAD ESCOLARIDAD ⋯ TURISMO INTERNET VIOLENCIA VIDA CELULAR DESERCION
# 1  98          13.79       ⋯  2.611  91.49    38.3      78.2 145.76  2.26
# 2 100          13.88       ⋯  0.945  94.67    39.5      81.7 148.37  5.60
# 3  98          14.75       ⋯  0.300  78.70    39.5      74.4 218.43  5.93
# 4 100          15.40       ⋯ 11.900  82.00     9.2      83.0 158.13  1.32
# 5  76          14.53       ⋯  0.225  68.77    39.5      78.8 110.06  3.63
# 6  98          13.33       ⋯  7.126  90.40    39.5      77.0 178.06  8.04
#   PRISION RENOVABLE PARLAMENTO INMIGRANTES
# 1  60     0.00       0.00      73.82
# 2 122     3.98      28.33      43.25
# 3 137     0.00       1.54      60.21
# 4 230     2.79      25.25      42.93
# 5 122     0.00      23.17      49.35
# 6 238     0.08      17.50      83.75

# %%
summary(datos_Per$IDH)

Min. 1stQu. Median Mean 3rdQu. Max.
0.4113 0.5863 0.7241 0.6950 0.7980 0.9155
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#  0.4113  0.5863  0.7241  0.6950  0.7980  0.9155

# %%
datosP %>%
  filter(IDH >= quantile(IDH,0.97) | IDH <= quantile(IDH,0.03)) %>%
  select(PAIS,PIB,IDH)
# Out:
#    PAIS                     PIB        IDH
# 1  Norway                   62.4508261 0.9439
# 2  Switzerland              54.7011508 0.9296
# 3  Netherlands              44.9452511 0.9218
# 4  Germany                  43.2065689 0.9161
# 5  Australia                42.8308331 0.9350
# 6  Denmark                  41.9878874 0.9233
# 7  Chad                      2.0218324 0.3919
# 8  Burkina Faso              1.5819309 0.4023
# 9  Eritrea                   1.1574293 0.3909
# 10 Niger                     0.8866581 0.3483
# 11 Burundi                   0.7468267 0.3999
# 12 Central African Republic  0.5849220 0.3501

# %%
# datos outleirs
datosP %>%
  filter(IDH >= quantile(IDH,0.97) | IDH <= quantile(IDH,0.03)) %>%
  select(PAIS,PIB,IDH)
# Out:
#    PAIS                     PIB        IDH
# 1  Norway                   62.4508261 0.9439
# 2  Switzerland              54.7011508 0.9296
# 3  Netherlands              44.9452511 0.9218
# 4  Germany                  43.2065689 0.9161
# 5  Australia                42.8308331 0.9350
# 6  Denmark                  41.9878874 0.9233
# 7  Chad                      2.0218324 0.3919
# 8  Burkina Faso              1.5819309 0.4023
# 9  Eritrea                   1.1574293 0.3909
# 10 Niger                     0.8866581 0.3483
# 11 Burundi                   0.7468267 0.3999
# 12 Central African Republic  0.5849220 0.3501

# %%
ggplot(mpg, aes(x = displ, y = hwy)) +
  geom_point() +
  geom_smooth(method = "lm")




plot(datos_Per$IDH)

plot(datos_Per$PIB,datos_Per$IDH)

summary(datos_Per$IDH)
# Out:
# plot without title
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#  0.4113  0.5863  0.7241  0.6950  0.7980  0.9155
# plot without title
